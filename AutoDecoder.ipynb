# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras

from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import Progbar

tf.random.set_seed(0)

# %%
epochs = 4000
batch_size = 64
learning_rate = 5e-5

# %%
train = pd.read_csv("./data/train_data.csv")
test = pd.read_csv("./data/test_data.csv")
train = train.drop(train.iloc[581:597,:].index.values) # motor vibe 중 이상치 데이터 삭제

ss = RobustScaler()

scaled_train = ss.fit_transform(train)
scaled_test = ss.transform(test)

train_data = scaled_train
test_data = scaled_test

# %%
loss_function = keras.losses.MeanSquaredError()
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

# %%
class AutoDecoder(tf.keras.Model):
    def __init__(self):
        super(AutoDecoder, self).__init__()
        self.decoder1 = keras.layers.Dense(64, activation="relu") #
        self.decoder2 = keras.layers.Dense(128, activation="relu")
        self.decoder3 = keras.layers.Dense(256, activation="relu")
        self.encoder1 = keras.layers.Dense(256, activation="relu")
        self.encoder2 = keras.layers.Dense(128, activation="relu")
        self.encoder3 = keras.layers.Dense(64, activation="relu")
        self.fc = keras.layers.Dense(units=8,input_shape=[2463, 1, 8])

    def call(self, inputs, training=True):
        if training:
            self.decoder1.trainable = True
            self.decoder2.trainable = True
            self.decoder3.trainable = True
            self.encoder1.trainable = True
            self.encoder2.trainable = True
            self.encoder3.trainable = True
            self.fc.trainable = True

        else:
            self.decoder1.trainable = False
            self.decoder2.trainable = False
            self.decoder3.trainable = False
            self.encoder1.trainable = False
            self.encoder2.trainable = False
            self.encoder3.trainable = False
            self.fc.trainable = False

        x = self.decoder1(inputs)
        x = self.decoder2(x)
        x = self.decoder3(x)
        x = self.encoder1(x)
        x = self.encoder2(x)
        x = self.encoder3(x)
        x = self.fc(x)

        return x
    
    def train(self):
        self.decoder1.trainable = True
        self.decoder2.trainable = True
        self.decoder3.trainable = True
        self.encoder1.trainable = True
        self.encoder2.trainable = True
        self.encoder3.trainable = True
        self.fc.trainable = True

# %%
class Trainer:
    def __init__(self, model, epochs, batch, loss_function, optimizer, patience=10):
        self.model = model
        self.epochs = epochs
        self.batch = batch
        self.loss_function = loss_function
        self.optimizer = optimizer
        self.patience = patience
        self.min_loss = np.Inf
        self.counter = 0
        self.history = {'train_loss':[], 'val_loss':[]}

    def train(self, train_data, valid=False):
        if valid == False:
            valid_dataset = []
            train_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_data)).batch(batch_size)
        else:
            train_dataset, valid_dataset = train_test_split(train_data, test_size=0.2, stratify=train_data[:, 7], random_state=0)
            n_train = len(train_dataset)
            n_val = len(valid_dataset)
            # train_dataset's shape : [step, batch_x_train, batch_y_train]
            train_dataset = tf.data.Dataset.from_tensor_slices((train_dataset, train_dataset)).batch(batch_size)
            valid_dataset = tf.data.Dataset.from_tensor_slices((valid_dataset, valid_dataset)).batch(batch_size)
            
        for epoch in range(self.epochs):
            self.model.train()
            print("\nStart of epoch %d" % (epoch,))

            # progress bar
            progBar = Progbar(len(train_dataset) * self.batch, stateful_metrics=['train_loss', 'val_loss'])
            total_loss = 0
            step = 0

            # start train
            for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
                with tf.GradientTape() as tape:
                    logits = self.model(x_batch_train, training=True)
                    loss = self.loss_function(y_batch_train, logits)
                grads = tape.gradient(loss, self.model.trainable_weights)
                self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))

                total_loss += loss
                if valid == False:
                    values = [('train_loss', loss)]
                    progBar.update((step + 1) * self.batch, values=values)
            train_loss = total_loss / n_train
            self.history['train_loss'].append(train_loss)
            
            # Calculate validation loss
            if n_val:
                # if validation set exists, do validation
                valid_loss = self.evaluate(valid_dataset)
                valid_loss /= n_val
                self.history['val_loss'].append(valid_loss)
                
                # Check if validation loss has improved, if not increase counter
                if valid_loss >= self.min_loss:
                    self.counter += 1
                else:
                    self.min_loss = valid_loss
                    self.counter = 0
                
                # Stop training if counter has reached patience
                if self.counter >= self.patience:
                    print("Validation loss did not improve for %d epochs. Training stopped." % (self.patience,))
                    print(f"Best Validation Loss : {self.min_loss}")
                    break

                values = [('train_loss', train_loss), ('val_loss', valid_loss)]
                progBar.update(len(train_dataset) * self.batch, values=values, finalize=True)

        plot_graph(self.history)

    def evaluate(self, dataset):
        total_loss = 0
        for x, y in dataset:
            logits = self.model(x, training=False)
            loss = self.loss_function(y, logits)
            total_loss += loss
            
        return total_loss
    
def plot_graph(history, start=0):
    train_data = history["train_loss"][start:]
    val_data = history["val_loss"][start:]
    n_train = len(train_data)

    gap = n_train // 5

    plt.plot(train_data, linewidth=2, label="train")
    plt.plot(val_data, linewidth=2, label="val")
    
    plt.xticks(range(0, n_train+1, gap), range(start, start+n_train+1, gap))
    plt.legend(loc="upper right")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.show()

# %%
ad = AutoDecoder()
ad.build(input_shape=(None, 64, 8))
ad.summary()

trainer = Trainer(model=ad,
                  epochs=epochs,
                  loss_function=loss_function,
                  optimizer=optimizer,
                  batch=batch_size,
                  patience=20)
trainer.train(train_data=train_data,
              valid=True)
# Out:
# Model: "auto_decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               multiple                  576
#
#  dense_1 (Dense)             multiple                  8320
#
#  dense_2 (Dense)             multiple                  33024
#
#  dense_3 (Dense)             multiple                  65792
#
#  dense_4 (Dense)             multiple                  32896
#
#  dense_5 (Dense)             multiple                  8256
#
#  dense_6 (Dense)             multiple                  520
#
# =================================================================
# Total params: 149,384
# Trainable params: 149,384
# Non-trainable params: 0
# _________________________________________________________________
#
# Start of epoch 0
# 1984/1984 [==============================] - 0s 101us/step - train_loss: 0.0059 - val_loss: 0.0051
#
# Start of epoch 1
# 1984/1984 [==============================] - 0s 94us/step - train_loss: 0.0052 - val_loss: 0.0043
#
# Start of epoch 2
# 1984/1984 [==============================] - 0s 94us/step - train_loss: 0.0041 - val_loss: 0.0030
#
# Start of epoch 3
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 0.0026 - val_loss: 0.0016
#
# Start of epoch 4
# 1984/1984 [==============================] - 0s 94us/step - train_loss: 0.0012 - val_loss: 7.5336e-04
#
# Start of epoch 5
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 5.2799e-04 - val_loss: 3.6331e-04
#
# Start of epoch 6
# 1984/1984 [==============================] - 0s 103us/step - train_loss: 2.3868e-04 - val_loss: 1.5085e-04
#
# Start of epoch 7
# 1984/1984 [==============================] - 0s 95us/step - train_loss: 9.7358e-05 - val_loss: 6.4453e-05
#
# Start of epoch 8
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 4.6243e-05 - val_loss: 3.6038e-05
#
# Start of epoch 9
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 2.7795e-07 - val_loss: 3.8688e-07
#
# Start of epoch 79
# 1984/1984 [==============================] - 0s 94us/step - train_loss: 2.7495e-07 - val_loss: 3.8355e-07
#
# Start of epoch 80
# 1984/1984 [==============================] - 0s 93us/step - train_loss: 2.7214e-07 - val_loss: 3.7950e-07
#
# Start of epoch 81
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.6907e-07 - val_loss: 3.7672e-07
#
# Start of epoch 82
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2.6606e-07 - val_loss: 3.7288e-07
#
# Start of epoch 83
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.6304e-07 - val_loss: 3.7035e-07
#
# Start of epoch 84
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2.5998e-07 - val_loss: 3.6684e-07
#
# Start of epoch 85
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2.5705e-07 - val_loss: 3.6404e-07
#
# Start of epoch 86
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.5424e-07 - val_loss: 3.6060e-07
#
# Start of epoch 87
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.5138e-07 - val_loss: 3.5821e-07
#
# Start of epoch 88
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.4880e-07 - val_loss: 3.5566e-07
#
# Start of epoch 89
# 1984/1984 [==============================] - 0s 98us/step - train_loss: 2.4633e-07 - val_loss: 3.5338e-07
#
# Start of epoch 90
# 1984/1984 [==============================] - 0s 98us/step - train_loss: 2.4410e-07 - val_loss: 3.5174e-07
#
# Start of epoch 91
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.4207e-07 - val_loss: 3.4991e-07
#
# Start of epoch 92
# 1984/1984 [==============================] - 0s 93us/step - train_loss: 2.4010e-07 - val_loss: 3.4869e-07
#
# Start of epoch 93
# 1984/1984 [==============================] - 0s 118us/step - train_loss: 2.3833e-07 - val_loss: 3.4707e-07
#
# Start of epoch 94
# 1984/1984 [==============================] - 0s 103us/step - train_loss: 2.3662e-07 - val_loss: 3.4565e-07
#
# Start of epoch 95
# 1984/1984 [==============================] - 0s 99us/step - train_loss: 2.3495e-07 - val_loss: 3.4405e-07
#
# Start of epoch 96
# 1984/1984 [==============================] - 0s 93us/step - train_loss: 2.3348e-07 - val_loss: 3.4290e-07
#
# Start of epoch 97
# 1984/1984 [==============================] - 0s 105us/step - train_loss: 2.3181e-07 - val_loss: 3.4081e-07
#
# Start of epoch 98
# 1984/1984 [==============================] - 0s 114us/step - train_loss: 2.3024e-07 - val_loss: 3.3921e-07
#
# Start of epoch 99
# 1984/1984 [==============================] - 0s 93us/step - train_loss: 2.2867e-07 - val_loss: 3.3704e-07
#
# Start of epoch 100
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.2706e-07 - val_loss: 3.3471e-07
#
# Start of epoch 101
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.2551e-07 - val_loss: 3.3294e-07
#
# Start of epoch 102
# 1984/1984 [==============================] - 0s 88us/step - train_loss: 2.2396e-07 - val_loss: 3.3134e-07
#
# Start of epoch 103
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.2275e-07 - val_loss: 3.2966e-07
#
# Start of epoch 104
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.2154e-07 - val_loss: 3.2872e-07
#
# Start of epoch 105
# 1984/1984 [==============================] - 0s 106us/step - train_loss: 2.2039e-07 - val_loss: 3.2743e-07
#
# Start of epoch 106
# 1984/1984 [==============================] - 0s 94us/step - train_loss: 2.1928e-07 - val_loss: 3.2613e-07
#
# Start of epoch 107
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 2.1828e-07 - val_loss: 3.2448e-07
#
# Start of epoch 108
# 1984/1984 [==============================] - 0s 102us/step - train_loss: 2.1699e-07 - val_loss: 3.2243e-07
#
# Start of epoch 109
# 1984/1984 [==============================] - 0s 96us/step - train_loss: 2.1566e-07 - val_loss: 3.2011e-07
#
# Start of epoch 110
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2.1419e-07 - val_loss: 3.1776e-07
#
# Start of epoch 111
# 1984/1984 [==============================] - 0s 103us/step - train_loss: 2.1271e-07 - val_loss: 3.1525e-07
#
# Start of epoch 112
# 1984/1984 [==============================] - 0s 102us/step - train_loss: 2.1094e-07 - val_loss: 3.1276e-07
#
# Start of epoch 113
# 1984/1984 [==============================] - 0s 93us/step - train_loss: 2.0913e-07 - val_loss: 3.1051e-07
#
# Start of epoch 114
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.0731e-07 - val_loss: 3.0835e-07
#
# Start of epoch 115
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 2.0581e-07 - val_loss: 3.0615e-07
#
# Start of epoch 116
# 1984/1984 [==============================] - 0s 103us/step - train_loss: 2.0418e-07 - val_loss: 3.0428e-07
#
# Start of epoch 117
# 1984/1984 [==============================] - 0s 92us/step - train_loss: 2.0310e-07 - val_loss: 3.0237e-07
#
# Start of epoch 118
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 2.0191e-07 - val_loss: 3.0143e-07
#
# Start of epoch 119
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.0105e-07 - val_loss: 2.9984e-07
#
# Start of epoch 120
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 2.0027e-07 - val_loss: 2.9984e-07
#
# Start of epoch 121
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.9992e-07 - val_loss: 2.9880e-07
#
# Start of epoch 122
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9942e-07 - val_loss: 2.9872e-07
#
# Start of epoch 123
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 1.9907e-07 - val_loss: 2.9818e-07
#
# Start of epoch 124
# 1984/1984 [==============================] - 0s 101us/step - train_loss: 1.9849e-07 - val_loss: 2.9814e-07
#
# Start of epoch 125
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.9829e-07 - val_loss: 2.9772e-07
#
# Start of epoch 126
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9787e-07 - val_loss: 2.9731e-07
#
# Start of epoch 127
# 1984/1984 [==============================] - 0s 88us/step - train_loss: 1.9745e-07 - val_loss: 2.9695e-07
#
# Start of epoch 128
# 1984/1984 [==============================] - 0s 88us/step - train_loss: 1.9701e-07 - val_loss: 2.9621e-07
#
# Start of epoch 129
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9630e-07 - val_loss: 2.9630e-07
#
# Start of epoch 130
# 1984/1984 [==============================] - 0s 110us/step - train_loss: 1.9622e-07 - val_loss: 2.9577e-07
#
# Start of epoch 131
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9584e-07 - val_loss: 2.9572e-07
#
# Start of epoch 132
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9561e-07 - val_loss: 2.9590e-07
#
# Start of epoch 133
# 1984/1984 [==============================] - 0s 88us/step - train_loss: 1.9559e-07 - val_loss: 2.9585e-07
#
# Start of epoch 134
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.9500e-07 - val_loss: 2.9835e-07
#
# Start of epoch 135
# 1984/1984 [==============================] - 0s 99us/step - train_loss: 1.9535e-07 - val_loss: 2.9961e-07
#
# Start of epoch 136
# 1984/1984 [==============================] - 0s 91us/step - train_loss: 1.9577e-07 - val_loss: 3.0114e-07
#
# Start of epoch 137
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9688e-07 - val_loss: 3.0237e-07
#
# Start of epoch 138
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9612e-07 - val_loss: 3.0272e-07
#
# Start of epoch 139
# 1984/1984 [==============================] - 0s 100us/step - train_loss: 1.9590e-07 - val_loss: 3.0322e-07
#
# Start of epoch 140
# 1984/1984 [==============================] - 0s 97us/step - train_loss: 1.9529e-07 - val_loss: 3.0418e-07
#
# Start of epoch 141
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.9507e-07 - val_loss: 3.0406e-07
#
# Start of epoch 142
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9455e-07 - val_loss: 3.0425e-07
#
# Start of epoch 143
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9365e-07 - val_loss: 3.0586e-07
#
# Start of epoch 144
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9313e-07 - val_loss: 3.0486e-07
#
# Start of epoch 145
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9245e-07 - val_loss: 3.0519e-07
#
# Start of epoch 146
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.9155e-07 - val_loss: 3.0410e-07
#
# Start of epoch 147
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.9081e-07 - val_loss: 3.0359e-07
#
# Start of epoch 148
# 1984/1984 [==============================] - 0s 90us/step - train_loss: 1.8961e-07 - val_loss: 3.0211e-07
#
# Start of epoch 149
# 1984/1984 [==============================] - 0s 88us/step - train_loss: 1.8872e-07 - val_loss: 3.0024e-07
#
# Start of epoch 150
# 1984/1984 [==============================] - 0s 89us/step - train_loss: 1.8703e-07 - val_loss: 2.9773e-07
#
# Start of epoch 151
# Validation loss did not improve for 20 epochs. Training stopped.
# Best Validation Loss : 2.957156368665892e-07

# %%
plot_graph(trainer.history, 30)

# %%
train_pred = ad.predict(train_data)
train_mse = np.mean(np.power(train_data - train_pred, 2), axis=1)
threshold = train_mse.max()

pred = ad.predict(test_data)

mse = np.mean(np.power(test_data - pred, 2), axis=1)
error_df = pd.DataFrame({"reconstruction_error" : mse, 'type' : test.type})
error_df["reconstruction_error"].plot(kind="hist",bins=30)
plt.show()
# Out:
# 2023-09-07 14:54:47.145000: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
sub = pd.read_csv("./data/answer_sample.csv")

error_df['label'] = 0

index = error_df.reconstruction_error >= threshold
error_df.iloc[index, 2] = 1

sub["label"] = error_df["label"]

print(sub["label"].value_counts())
print("\ntype별 개수")
print(sub[sub.label == 1].type.value_counts())
# Out:
# 0    7049
# 1     340
# Name: label, dtype: int64
#
# type별 개수
# 0    143
# 6    101
# 5     30
# 3     26
# 2     23
# 4     13
# 7      4
# Name: type, dtype: int64

# %%
from sklearn.decomposition import PCA

ori_test = pd.read_csv('./data/test_data.csv')
ori_test["label"] = sub["label"].values

outliers=sub.loc[ori_test['label']==1]
outlier_index=list(outliers.index)

pca = PCA(2)
res = pd.DataFrame(pca.fit_transform(ori_test))

plt.title("result - PCA")
b1 = plt.scatter(res[0], res[1], c='gray', s=20, label='normal')
b2 = plt.scatter(res.iloc[outlier_index, 0], res.iloc[outlier_index, 1], c='red', s=20, edgecolor="red", label='outliers')
plt.legend()
plt.show()

# %%
col_threshold = np.power(train_data - train_pred, 2).max(axis=0)

error_df = pd.DataFrame({'anomalies' : (np.power(test_data - pred, 2) > col_threshold).sum(axis=1), 'type' : test.type})
error_df[error_df['anomalies'] != 0] = 1

sub = pd.read_csv("./data/answer_sample.csv")

sub["label"] = error_df["anomalies"]

print(sub["label"].value_counts())
print("\ntype별 개수")
print(sub[sub.label == 1].type.value_counts())
# Out:
# 0    7047
# 1     342
# Name: label, dtype: int64
#
# type별 개수
# 0    143
# 6    101
# 5     30
# 3     26
# 2     25
# 4     13
# 7      4
# Name: type, dtype: int64

# %%
from sklearn.decomposition import PCA

ori_test = pd.read_csv('./data/test_data.csv')
ori_test["label"] = sub["label"].values

outliers=sub.loc[ori_test['label']==1]
outlier_index=list(outliers.index)

pca = PCA(2)
res = pd.DataFrame(pca.fit_transform(ori_test))

plt.title("result - PCA")
b1 = plt.scatter(res[0], res[1], c='gray', s=20, label='normal')
b2 = plt.scatter(res.iloc[outlier_index, 0], res.iloc[outlier_index, 1], c='red', s=20, edgecolor="red", label='outliers')
plt.legend()
plt.show()

# %%
sub.to_csv("AD.csv", index=False)
